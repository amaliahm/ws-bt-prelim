# %%
from matplotlib.widgets import Slider
import matplotlib.pyplot as plt
import nibabel as nib
import numpy as np

# %%
# %matplotlib widget

# %%
path = "/run/media/amina/disk/dataset/BTReportBraTS23/BraTS-GLI/ASNR-MICCAI-BraTS2023-GLI-Challenge-TrainingData/BraTS-GLI-00525-001/BraTS-GLI-00525-001-seg.nii.gz"

data = nib.load(path).get_fdata()
n_slices = data.shape[2]

fig, ax = plt.subplots(figsize=(6, 6))
plt.subplots_adjust(bottom=0.15)

im = ax.imshow(data[:, :, n_slices//2].T, cmap="gray", origin="lower")
ax.set_title("Axial FLAIR — use slider")
ax.axis("off")

ax_slider = plt.axes([0.2, 0.05, 0.6, 0.03])
slider = Slider(ax_slider, "Slice", 0, n_slices - 1,
                valinit=n_slices // 2, valstep=1)

def update(val):
    im.set_data(data[:, :, int(slider.val)].T)
    fig.canvas.draw_idle()

slider.on_changed(update)
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
seg = nib.load(path).get_fdata()
print(np.unique(seg))
# Out:
# [0. 1. 2. 3.]

# %%
path = "/home/amina/amina/ws-bt-prelim/spring_05/datasets/BTReport-BraTs23/BraTS-GLI-00000-000/BraTS-GLI-00000-000-t1c.nii.gz"

data = nib.load(path).get_fdata()
n_slices = data.shape[2]

fig, ax = plt.subplots(figsize=(6, 6))
plt.subplots_adjust(bottom=0.15)

im = ax.imshow(data[:, :, n_slices//2].T, cmap="gray", origin="lower")
ax.set_title("Axial FLAIR — use slider")
ax.axis("off")

ax_slider = plt.axes([0.2, 0.05, 0.6, 0.03])
slider = Slider(ax_slider, "Slice", 0, n_slices - 1,
                valinit=n_slices // 2, valstep=1)

def update(val):
    im.set_data(data[:, :, int(slider.val)].T)
    fig.canvas.draw_idle()

slider.on_changed(update)
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
path = "/home/amina/amina/ws-bt-prelim/spring_05/datasets/BTReport-BraTs23/BraTS-GLI-00000-000/BraTS-GLI-00000-000-t1n.nii.gz"

data = nib.load(path).get_fdata()
n_slices = data.shape[2]

fig, ax = plt.subplots(figsize=(6, 6))
plt.subplots_adjust(bottom=0.15)

im = ax.imshow(data[:, :, n_slices//2].T, cmap="gray", origin="lower")
ax.set_title("Axial FLAIR — use slider")
ax.axis("off")

ax_slider = plt.axes([0.2, 0.05, 0.6, 0.03])
slider = Slider(ax_slider, "Slice", 0, n_slices - 1,
                valinit=n_slices // 2, valstep=1)

def update(val):
    im.set_data(data[:, :, int(slider.val)].T)
    fig.canvas.draw_idle()

slider.on_changed(update)
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
path = "/home/amina/amina/ws-bt-prelim/spring_05/datasets/BTReport-BraTs23/BraTS-GLI-00000-000/BraTS-GLI-00000-000-t2f.nii.gz"

data = nib.load(path).get_fdata()
n_slices = data.shape[2]

fig, ax = plt.subplots(figsize=(6, 6))
plt.subplots_adjust(bottom=0.15)

im = ax.imshow(data[:, :, n_slices//2].T, cmap="gray", origin="lower")
ax.set_title("Axial FLAIR — use slider")
ax.axis("off")

ax_slider = plt.axes([0.2, 0.05, 0.6, 0.03])
slider = Slider(ax_slider, "Slice", 0, n_slices - 1,
                valinit=n_slices // 2, valstep=1)

def update(val):
    im.set_data(data[:, :, int(slider.val)].T)
    fig.canvas.draw_idle()

slider.on_changed(update)
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
path = "/home/amina/amina/ws-bt-prelim/spring_05/datasets/BTReport-BraTs23/BraTS-GLI-00000-000/BraTS-GLI-00000-000-t2w.nii.gz"

data = nib.load(path).get_fdata()
n_slices = data.shape[2]

fig, ax = plt.subplots(figsize=(6, 6))
plt.subplots_adjust(bottom=0.15)

im = ax.imshow(data[:, :, n_slices//2].T, cmap="gray", origin="lower")
ax.set_title("Axial FLAIR — use slider")
ax.axis("off")

ax_slider = plt.axes([0.2, 0.05, 0.6, 0.03])
slider = Slider(ax_slider, "Slice", 0, n_slices - 1,
                valinit=n_slices // 2, valstep=1)

def update(val):
    im.set_data(data[:, :, int(slider.val)].T)
    fig.canvas.draw_idle()

slider.on_changed(update)
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
path = "//home/amina/amina/ws-bt-prelim/spring_05/datasets/BTReport-BraTs23/BraTS-GLI-00000-000/"

data = nib.load(path).get_fdata()
n_slices = data.shape[2]

fig, ax = plt.subplots(figsize=(6, 6))
plt.subplots_adjust(bottom=0.15)

im = ax.imshow(data[:, :, n_slices//2].T, cmap="gray", origin="lower")
ax.set_title("Axial FLAIR — use slider")
ax.axis("off")

ax_slider = plt.axes([0.2, 0.05, 0.6, 0.03])
slider = Slider(ax_slider, "Slice", 0, n_slices - 1,
                valinit=n_slices // 2, valstep=1)

def update(val):
    im.set_data(data[:, :, int(slider.val)].T)
    fig.canvas.draw_idle()

slider.on_changed(update)
plt.show()
