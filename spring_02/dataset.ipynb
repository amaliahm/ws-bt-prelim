# %% [markdown]
# TextBraTs 2020

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
text_brats = np.load("TextBraTs/TextBraTSData/BraTS20_Training_005/BraTS20_Training_005_flair_text.npy")

print(type(text_brats))
print(text_brats.shape)
# Out:
# <class 'numpy.ndarray'>
# (1, 128, 768)

# %%
text_brats = text_brats.squeeze() 
print(text_brats.shape)     
plt.imshow(text_brats, cmap="gray")
plt.axis("off")
plt.show()
# Out:
# (128, 768)
